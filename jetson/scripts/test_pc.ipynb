# %%
# !Get-PnpDevice -Class Ports 
# 获取com端口号
# !netstat -ano
# Out:
# 'Get-PnpDevice' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# �����
#
#   Э��  ���ص�ַ          �ⲿ��ַ        ״̬           PID
#   TCP    0.0.0.0:16             0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:22             0.0.0.0:0              LISTENING       5660
#   TCP    0.0.0.0:32             0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:81             0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:135            0.0.0.0:0              LISTENING       1996
#   TCP    0.0.0.0:445            0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:1001           0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:2259           0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:2343           0.0.0.0:0              LISTENING       5720
#   TCP    0.0.0.0:3580           0.0.0.0:0              LISTENING       5692
#   TCP    0.0.0.0:4002           0.0.0.0:0              LISTENING       6848
# ...
